# %%
cgpa={1:9.1,2:8.4,3:6.5,4:6.7,5:7.8,7:9.1,8:5.1}
print("dictionary",cgpa)
print("total elements",len(cgpa))
print("type of object",type(cgpa))
print("keys",cgpa.keys())
print("cgpa of 7",cgpa[7])
print("cgpa of 5",cgpa[5])
# Out:
# dictionary {1: 9.1, 2: 8.4, 3: 6.5, 4: 6.7, 5: 7.8, 7: 9.1, 8: 5.1}
# total elements 7
# type of object <class 'dict'>
# keys dict_keys([1, 2, 3, 4, 5, 7, 8])
# cgpa of 7 9.1
# cgpa of 5 7.8
