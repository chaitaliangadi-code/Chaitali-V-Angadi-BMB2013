# %%
crops={"rice":120,"wheat":85,"maize":60}
print(len(crops))
# Out:
# 3

# %%
print(crops['wheat'])
# Out:
#   File "/tmp/ipython-input-1901947959.py", line 2
#     print(yield[1])
#           ^
# SyntaxError: invalid syntax

# %%
print(crops["wheat"])
# Out:
# 85

# %%
crops.update({"pulses":45})
print(crops)
# Out:
# {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
print(list(crops.keys()))
print(list(crops.values()))
print(list(crops.items()))
# Out:
# ['rice', 'wheat', 'maize', 'pulses']
# [120, 85, 60, 45]
# [('rice', 120), ('wheat', 85), ('maize', 60), ('pulses', 45)]

# %%
crops["rice"]=120
print("after adding (120)",crops)
crops["rice"]=130
print("after updating (120)",crops)
# Out:
# after adding (120) {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# after updating (120) {'rice': 130, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
print(list(crops.keys()))
# Out:
# ['rice', 'wheat', 'maize', 'pulses']

# %%
print(list(crops.values()))
# Out:
# [130, 85, 60, 45]

# %%
print("is sugarcane cultivated by the farmer---->","sugarcane" in crops.keys())
# Out:
# is sugarcane cultivated by the farmer----> False

# %%
crops["wheat"]+=10
print(crops)
# Out:
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
print(sum(crops.values()))
# Out:
# 330

# %%
for crop_name, crop_yield_value in crops.items():
  print(f"{crop_name} yield is {crop_yield_value}")
# Out:
#   File "/tmp/ipython-input-1043111070.py", line 2
#     print(crops[i],"yield is",yield[i])
#                               ^
# SyntaxError: invalid syntax

# %%
for i in crops_yield():
  print(i,":",crops_yield[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4128141808.py in <cell line: 0>()
# ----> 1 for i in crops_yield():
#       2   print(i,":",crops_yield[i])
#
# NameError: name 'crops_yield' is not defined

# %%
keylist=list(crops.keys())
vallist=list(crops.values())
mdict={}
for i in range(len(keylist)):
  mdict[keylist[i]]=vallist[i]
print(mdict)
# Out:
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
dict1={'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}
dict2=dict1.copy()
print(dict1)
print(dict2)
# Out:
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
dict2.clear()
print(dict2)
# Out:
# {}

# %%
if jowar in crops:
  print("jowar is cultivated by the farmer")
else:
  print("jowar is not cultivated by the farmer")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1648691244.py in <cell line: 0>()
# ----> 1 if jowar in crops:
#       2   print("jowar is cultivated by the farmer")
#       3 else:
#       4   print("jowar is not cultivated by the farmer")
#
# NameError: name 'jowar' is not defined

# %%
if ("jowar" in crops.keys()):
  print("true")
else:
  print("false")
# Out:
# false

# %%
print("jowar yield:",dict1.get("jowar","not cultivated"))
# Out:
# jowar yield: not cultivated

# %%
dict1.pop("maize")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4053173946.py in <cell line: 0>()
# ----> 1 dict1.pop("maize")
#
# KeyError: 'maize'

# %%
dict1={"rice": 130, "wheat": 95, "maize": 60, "pulses": 45}
dict1.pop("maize")
print(dict1)
# Out:
# {'rice': 130, 'wheat': 95, 'pulses': 45}

# %%
del(dict1)
