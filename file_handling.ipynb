# %%
file=open("abc.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2749428419.py in <cell line: 0>()
# ----> 1 file=open("abc.txt","r")
#       2 content=file.read()
#       3 print(content)
#       4 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abc.txt'

# %%
file=open("gkvk.txt","w")
file.write("gkvkians")
file.close()

# %%
file=open("gkvk.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hello gkvkians

# %%
file=open("gkvk.txt","a")
file.write("\nthis is appended text")
file.close()
# Out:
# hello gkvkians

# %%
file=open("gkvk.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hello gkvkians
# this is appended text
# this is appended text

# %%
file=open("hello.txt","w")
file.write("hello")
file.close()

# %%
file=open("hello.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hello

# %%
file=open("hello.txt","a")
file.write("\nthis is appended text")
file.close()

# %%
file=open("hello.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hello
# this is appended text

# %%
file=open("charm.txt","w")
file.write("hello")
file.close()

# %%
with open("charm.txt","r") as file:
  print(file.read())
# Out:
# hello

# %%
with open("charm.txt","w") as file:
  file.write("good morning")

# %%
with open("charm.txt","r") as file:
  print(file.read())
# Out:
# good morning

# %%
try:
  file=open("namjoon.txt","r")
  content=file.read()
  print(content)
  file.close()
except:
  print("no such file")
# Out:
# no such file

# %%
try:
  file=open("charm.txt","r")
  content=file.read()
  print(content)
  file.close()
except:
  print("no such file")
# Out:
# good morning

# %%
try:
  with open("namjoon.txt","r") as file:
    line=f.read()
    print(line)
except:
  print("error!! no such file exists")
# Out:
# error!! no such file exists

# %%
try:
  a=20
  b=30
  c=a+d
  print(c)
except:
  print("some issue")
# Out:
# some issue

# %%
def expr(a,b):
  c=a/d
  print(c)
a=40
b=0
expr(a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-39992499.py in <cell line: 0>()
#       4 a=40
#       5 b=0
# ----> 6 expr(a,b)
#
# /tmp/ipython-input-39992499.py in expr(a, b)
#       1 def expr(a,b):
# ----> 2   c=a/d
#       3   print(c)
#       4 a=40
#       5 b=0
#
# NameError: name 'd' is not defined

# %%
def expr(a,b):
  try:
    c=a/b
  except ZeroDivisionError:
    print("divided by zero")
  except NameError:
    print("variable not declared")
  except:
    print("some error occured")
  else:
    print("executed without error")
    print("value of c",c)
  finally:
    print("end of program")
a=10
b=5
expr(b)
# Out:
# executed without error
# value of c 2.0
# end of program
