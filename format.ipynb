# %%
print  ("today is {3}.we are doing the course{1}.\
 as part of this learning {2}with {0}"\
      .format("handson","AIML","python","thursday"))
# Out:
# today is thursday.we are doing the courseAIML. as part of this learning pythonwith handson

# %%
a=int(input("enter a number"))
print(a)
print(type(a))
# Out:
# enter a number12
# 12
# <class 'int'>

# %%
a=int(input("enter a number"))
b=int(input("enter a another number"))
print(a*b)
print(type(a))
# Out:
# enter a number5
# enter a another number5
# 25
# <class 'int'>

# %%
a=(input("enter your name"))
b=int(input("enter your age"))
c=b+10
print("my name is {}and may age after 10 years will be{}".format(a,c))
# Out:
# enter your namechinmayee
# enter your age20
# my name is chinmayeeand may age after 10 years will be30
