# %%
list1=[10,20,30,40,50,60,70,80]
list1[-5:-1:-1]
# Out:
# []

# %%
list1[-5:-1:1]
# Out:
# [40, 50, 60, 70]

# %%
list1[-4:-1:1]
# Out:
# [50, 60, 70]

# %%
list1[-1:-5:-1]
# Out:
# [80, 70, 60, 50]

# %%
crops=["rice","wheat","maize","millet","pulses","cotton"]
crops[1:5]
