# %%
list1=[10,20,30,40,50,60]
list1[0]
# Out:
# 10

# %%
list1[2:4]
# Out:
# [30, 40]

# %%
list1[3:6]
# Out:
# [40, 50, 60]

# %%
list1[2:8]
# Out:
# [30, 40, 50, 60]

# %%
list1[2:5]
# Out:
# [30, 40, 50]

# %%
list1[1:4]
# Out:
# [20, 30, 40]

# %%
list1[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-90640660.py in <cell line: 0>()
# ----> 1 list1[8]
#
# IndexError: list index out of range

# %%
list1[ :4]
# Out:
# [10, 20, 30, 40]

# %%
list1[3: ]
# Out:
# [40, 50, 60]

# %%
list1[-3:-1]
# Out:
# [40, 50]

# %%
list1[-3:-5]
# Out:
# []

# %%
list1[5:3]
# Out:
# []

# %%
list1[1:6:2]
# Out:
# [20, 40, 60]

# %%
list1[1:6:1]
# Out:
# [20, 30, 40, 50, 60]

# %%
list1[1:6]
# Out:
# [20, 30, 40, 50, 60]

# %%
list1[1:6:3]
# Out:
# [20, 50]

# %%
list1[-5:-1]
# Out:
# [20, 30, 40, 50]

# %%
list1[-5:-1:2]
# Out:
# [20, 40]

# %%
list1[-5:-1:1]
# Out:
# [20, 30, 40, 50]

# %%
list1[-5:-1:3]
# Out:
# [20, 50]

# %%
crops=["rice","wheat","maize","millet","pulses","cotton"]
print( crops[1:5])
# Out:
# ['wheat', 'maize', 'millet', 'pulses']

# %%
crops[2:4]
# Out:
# ['maize', 'millet']

# %%
crops[-3:-3]
# Out:
# []

# %%
crops[4: ]
# Out:
# ['pulses', 'cotton']

# %%
st1=[10,20,30,40,50,60,70,80]
liist1[ :  :-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1568268477.py in <cell line: 0>()
#       1 st1=[10,20,30,40,50,60,70,80]
# ----> 2 lliist1[ :  :-1]
#
# NameError: name 'lliist1' is not defined

# %%
list1[-1:-5:-1]
# Out:
# [80, 70, 60, 50]

# %%
list1[-5:-1:-1]
# Out:
# []

# %%
list1[-5:-1:1]
# Out:
# [40, 50, 60, 70]

# %%
list1[ : :2]
# Out:
# [10, 30, 50, 70]

# %%
crops=["rice","wheat","maize","millet","pulses","cotton"]
crops[ : :2]
# Out:
# ['rice', 'maize', 'pulses']

# %%
crops[ : :-1]
# Out:
# ['cotton', 'pulses', 'millet', 'maize', 'wheat', 'rice']

# %%
numbers=[10,20,30,40,50,60]
for i in numbers:
   print(i+2)
   print(numbers)
# Out:
# 12
# [10, 20, 30, 40, 50, 60]
# 22
# [10, 20, 30, 40, 50, 60]
# 32
# [10, 20, 30, 40, 50, 60]
# 42
# [10, 20, 30, 40, 50, 60]
# 52
# [10, 20, 30, 40, 50, 60]
# 62
# [10, 20, 30, 40, 50, 60]

# %%
numbers=[10,20,30,40,50,60]
n=[]
for i in numbers:
  n.append(i+2)
print("new list",n)
print("original list",numbers)
# Out:
# new list [12, 22, 32, 42, 52, 62]
# original list [10, 20, 30, 40, 50, 60]

# %%
num=[10,20,30,40,50,60]
a=[i+2 for i in num]
print("new list",a)
print("original list",num)
# Out:
# new list [12, 22, 32, 42, 52, 62]
# original list [10, 20, 30, 40, 50, 60]

# %%
num=[10,20,30,40,50,60]
a=[i+5889 for i in num]
print("new list",a)
print("original list",num)
# Out:
# new list [5899, 5909, 5919, 5929, 5939, 5949]
# original list [10, 20, 30, 40, 50, 60]

# %%
num=[10,20,30,40,50,60]
n=[ i for i in num  if i%4==0 ]
print("num divided by 4",n)
print("original list",num)
# Out:
# num divided by 4 [20, 40, 60]
# original list [10, 20, 30, 40, 50, 60]

# %%
numbers=[10,20,30,40,50,60]
n=[]
for i in numbers:
  if i%4==0:
    n.append(i)
print("new list",n)
print("original list",numbers)
# Out:
# new list [20, 40, 60]
# original list [10, 20, 30, 40, 50, 60]

# %%
numbers=[10,21,30,41,50,61]
n=["even" if i%2==0 else"odd" for i in numbers]
print(n)
# Out:
# ['even', 'odd', 'even', 'odd', 'even', 'odd']
