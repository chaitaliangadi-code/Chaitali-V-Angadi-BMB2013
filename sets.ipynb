# %%
s={'e','a','b','e','f','e','f'}
print("number of elements",len(s))
print("type of object",type(s))
# Out:
# number of elements 4
# type of object <class 'set'>

# %%
print("s",s)
print("")
for i in s:
  print(i)
# Out:
# s {'a', 'e', 'b', 'f'}
#
# a
# e
# b
# f

# %%
print("s",s)
print(s[2])
# Out:
# s {'a', 'e', 'b', 'f'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4103530056.py in <cell line: 0>()
#       1 print("s",s)
# ----> 2 print(s[2])
#
# TypeError: 'set' object is not subscriptable

# %%
s.add("d")
print("after adding (d)",s)
# Out:
# after adding (d) {'f', 'a', 'e', 'd', 'b'}

# %%
s1={'a','b','e','f'}
s2={'d','e','f','g'}
s1.update(s2)
print(s1)
# Out:
# {'f', 'a', 'e', 'd', 'g', 'b'}

# %%
s1.remove('e')
print(s1)
# Out:
# {'f', 'a', 'd', 'g', 'b'}

# %%
s1.discard('f')
print(s1)
# Out:
# {'a', 'd', 'g', 'b'}

# %%
s1.pop()
print(s1)
# Out:
# {'d', 'g', 'b'}

# %%
s.pop()
# Out:
# 'a'

# %%
s.clear()
print(s)
# Out:
# set()

# %%
del s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-555664742.py in <cell line: 0>()
# ----> 1 del s
#
# NameError: name 's' is not defined

# %%
s={1,2,3,4,5,6,8,9}
print("s",s)
print("sum",sum(s))
print("avearge",sum(s)/len(s))
print("maximum",max(s))
print("minimum",min(s))
print("is 2 present",2 in s)
print("is 11 present",11 in s)
# Out:
# s {1, 2, 3, 4, 5, 6, 8, 9}
# sum 38
# avearge 4.75
# maximum 9
# minimum 1
# is 2 present True
# is 11 present False

# %%
a={1,2,3,4,5,6}
b={10,20,30,40,50,60}
print("union of a and b",a.union(b))
print("intersection of a and b",a.intersection(b))
print("difference of a and b",a.difference(b))
# Out:
# union of a and b {1, 2, 3, 4, 5, 6, 40, 10, 50, 20, 60, 30}
# intersection of a and b set()
# difference of a and b {1, 2, 3, 4, 5, 6}
