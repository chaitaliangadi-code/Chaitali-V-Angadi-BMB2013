# %%
s={1,2,3,4}
print("s",s)
print("sum",sum(s))
# Out:
# s {1, 2, 3, 4}
# sum 10

# %%
print("average",sum(s)/len(s))
print(s)
# Out:
# average 2.5
# {1, 2, 3, 4}

# %%
print("maximum",max(s))
print(s)
# Out:
# maximum 4
# {1, 2, 3, 4}

# %%
print("minimum",min(s))
# Out:
# minimum 1

# %%
print("is 2 present:",2 in s)
# Out:
# is 2 present: True

# %%
print("is 10 present:",10 in s)
# Out:
# is 10 present: False

# %%
s1={'a','b','c','d'}
s2={'e','f','g','h'}
print("union of s1 and s2",s1.union(s2))
print("intersection of a and b",s1.intersection(s2))
print("difference of s1 and s2",s1.difference(s2))
# Out:
# union of s1 and s2 {'a', 'f', 'd', 'e', 'g', 'b', 'h', 'c'}
# intersection of a and b set()
# difference of s1 and s2 {'c', 'd', 'b', 'a'}

# %%
s1={'a','b','c','d'}
s2={'e','f','c','h'}
print("intersection of a and b",s1.intersection(s2))
# Out:
# intersection of a and b {'c'}
