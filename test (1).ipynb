# %%
nums=[1,2,3,4,5]
i=0
while i<len(nums):
  if nums[i]%2==0:
    nums.pop(i)
  else:
    i+=1
print(nums)
# Out:
# [1, 3, 5]

# %%
nums=[10,20,30]
i=0
while i<len(nums):
  print(nums[i])
  i+=1
# Out:
# 10
# 20
# 30

# %%
x=15
if x>10:
  print("a")
if x>5:
  print("b")
# Out:
# a
# b

# %%
nums=[1,2,3,4,5]
for n in nums:
  if n>3:
    print(n)
# Out:
# 4
# 5

# %%
x=25
if x>10:
  if x>20:
    print("a")
  else:
    print("b")
else:
  print("c")
# Out:
# a

# %%
nums=[3,6,9,12]
total=0
for n in nums:
  total+=n
print(total)
# Out:
# 30

# %%
nums=[1,2,3,4]
for n in nums:
  print(n)
# Out:
# 1
# 2
# 3
# 4

# %%
nums=[1,2,3,4]
squares=[]
for n in nums:
  squares.append(n**2)
print(squares)
# Out:
# [1, 4, 9, 16]

# %%
n=-3
if n>=0:
  if n==0:
    print("zero")
  else:
    print("positive")
else:
  print("negative")
# Out:
# negative

# %%
nums=[5,10,15]
for n in nums:
  n+=5
print(nums)
# Out:
# [5, 10, 15]

# %%
lst=[1,20,3,7]
for i in lst:
  print(i)
# Out:
# 1
# 20
# 3
# 7

# %%
for i in range(len(lst)):
  print(lst[i])
# Out:
# 1
# 20
# 3
# 7

# %%
nums=[1,2,3,4]
squares=*len(nums)
for i in range(len(nums)):
  squares[i]=nums[i]
print(nums)
# Out:
#   File "/tmp/ipython-input-1738815633.py", line 2
#     squares=*len(nums)
#             ^
# SyntaxError: can't use starred expression here

# %%
squares=[]
for i in range(len(nums)):
  nums[i]=nums[i]**2
  squares.append(nums[i])
print(squares)
# Out:
# [1, 16, 81, 256]
