# %%
T=("pratham","sharma",3.14,3)
print("type of object",type(T))
# Out:
# type of object <class 'tuple'>

# %%
print(len(T))
# Out:
# 4

# %%
print(type (T))
# Out:
# <class 'tuple'>

# %%
i=0
while i<len(T):
  printprint("")
(T[i])
  i+=1
# Out:
# pratham
# sharma
# 3.14
# 3
