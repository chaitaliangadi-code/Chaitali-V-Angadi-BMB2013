# %%
i=1
while(i<=10):
  if i==6:
    break
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,11):
  if i==6:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 7
# 8
# 9
# 10

# %%
for i in range(1,11):
  if i==6:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 7
# 8
# 9
# 10

# %%
i=2
while(i<=2):
  if(i%2==0):
    print(i)
    i+=2
# Out:
# Streaming output truncated to the last 5000 lines.
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# ...

# %%
i=1
while(i<=4):
  if i%2==0:
    print(i)
    i+=2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1081816075.py in <cell line: 0>()
#       1 i=1
# ----> 2 while(i<=4):
#       3   if i%2==0:
#       4     print(i)
#       5     i+=2
#
# KeyboardInterrupt:

# %%
for i in range(1,11):
  if i==4 or i==6:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 5
# 7
# 8
# 9
# 10

# %%
i=1
while(i<=20):
  if i%3==0:
    print(i)
  i+=1
# Out:
# 3
# 6
# 9
# 12
# 15
# 18

# %%
i=1
while(i<=10):
  if i==6:
    break
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
num=1
while num!=0:
  num=int(input("enter a number:"))
  print(num)
# Out:
# enter a number:5
# 5
# enter a number:6
# 6
# enter a number:7
# 7
# enter a number:8
# 8
# enter a number:9
# 9
# enter a number:2
# 2
# enter a number:4
# 4
# enter a number:0
# 0

# %%
password=""
while password!="Charm":
  password=input("enter the password")
print("access granted")
# Out:
# enter the passwordcharm
# enter the passwordCharm
# access granted

# %%
marks=-2
while(marks<0 or marks>100):
  marks=int(input("enter the marks:"))
print("marks:",marks)
# Out:
# enter the marks:-5
# enter the marks:5
# marks: 5

# %%
sum=0
for i in range(1,6):
  sum=sum+i
print(sum)
# Out:
#   File "/tmp/ipython-input-2164529461.py", line 1
#     for(i==1;i<=5;i=i+1)
#             ^
# SyntaxError: invalid syntax

# %%
i=1
sum=0
while(i<=5):
  sum=sum+i
  i=i+1
print(sum)
# Out:
# 15

# %%
i=1
sum=0
while(i>50):
  sum=sum+i
  i=i+1
print(sum)
# Out:
# 0

# %%
sum=0
for i in range(1,6):
  sum=sum+i
print(sum)
# Out:
# 15

# %%
sum=0
for i in range(1,51):
  sum=sum+i
print(sum)
# Out:
# 1275
