# %%
                                                                                                           pesticides=["neem oil","chlorpyrifos","malathion","imidacloprid","spinosad"]
effectiveness=[75,85,70,90,88]
for p,e in zip(pesticides,effectiveness):
    print(p,"effectiveness is",e)
# Out:
# neem oil effectiveness is 75
# chlorpyrifos effectiveness is 85
# malathion effectiveness is 70
# imidacloprid effectiveness is 90
# spinosad effectiveness is 88

# %%
pesticides=["neem oil","chlorpyrifos","malathion","imidacloprid","spinosad"]
effectiveness=[75,85,70,90,88]
max_effectivenes=max(zip(effectiveness,pesticides))
print(max_effectivenes)
print("pesticide with highest effectiveness:",max_effectivenes[0])
# Out:
# (90, 'imidacloprid')
# pesticide with highest effectiveness: 90

# %%
min_effectivenes=min(zip(effectiveness,pesticides))
print(min_effectivenes)
print("pesticide with least effectiveness:",min_effectivenes[0])
# Out:
# (70, 'malathion')
# pesticide with least effectiveness: 70

# %%
average_effectivenes=sum(effectiveness)/len(effectiveness)
print("average effectiveness:",average_effectivenes)
# Out:
# average effectiveness: 81.6

# %%
pesticides=["neem oil","chlorpyrifos","malathion","imidacloprid","spinosad"]
effectiveness=[75,85,70,90,88]
print("pesticide effectiveness")
for pesticide_effectiveness in effectiveness:
  print(pesticide_effectiveness,"%")
# Out:
# pesticide effectiveness
# 75 %
# 85 %
# 70 %
# 90 %
# 88 %

# %%
average_effectivenes=sum(effectiveness)/len(effectiveness)
print("average effectiveness:",average_effectivenes,"%")
# Out:
# average effectiveness: 81.6 %

# %%
for p,e in zip(pesticides,effectiveness):
 if e>=81.6:
  print(p)
# Out:
# chlorpyrifos
# imidacloprid
# spinosad

# %%
for p,e in zip(pesticides,effectiveness):
 if e>80:
  print(p)
# Out:
# chlorpyrifos
# imidacloprid
# spinosad

# %%
for p,e in zip(pesticides,effectiveness):
 if e<80:
  print(p)
# Out:
# neem oil
# malathion

# %%
count_less_than_80 = 0
for e in effectiveness:
    if e < 80:
        count_less_than_80 += 1
print(f"Number of pesticides with effectiveness less than 80: {count_less_than_80}")
# Out:
# Number of pesticides with effectiveness less than 80: 2

# %%
a=str(input("enter a pesticide"))
b=int(input("enter its effectiveness"))
print("pesticide is {} & its effectiveness after adding 5 is {}".format(a,b+5))
# Out:
# enter a pesticidemalathion
# enter its effectiveness70
# pesticide is malathion & its effectiveness after adding 5 is 75

# %%
for p,e in zip(pesticides,effectiveness):
 if e>=85:
  print("suitable for organic farming")
else:
   print("not suitable for organic farming")
# Out:
# suitable for organic farming
# suitable for organic farming
# suitable for organic farming
# not suitable for organic farming

# %%
pesticides=["neem oil","chlorpyrifos","malathion","imidacloprid","spinosad"]
effectiveness=[75,85,70,90,88]
if effectiveness>=85:
  print("suitable for organic farming")
else:
  print("not suitable for organic farming")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2634802440.py in <cell line: 0>()
#       1 pesticides=["neem oil","chlorpyrifos","malathion","imidacloprid","spinosad"]
#       2 effectiveness=[75,85,70,90,88]
# ----> 3 if effectiveness>=85:
#       4   print("suitable for organic farming")
#       5 else:
#
# TypeError: '>=' not supported between instances of 'list' and 'int'

# %%
pesticides=["neem oil","chlorpyrifos","malathion","imidacloprid","spinosad"]
effectiveness=[75,85,70,90,88]
pesticide_effectiveness.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1526763406.py in <cell line: 0>()
#       1 pesticides=["neem oil","chlorpyrifos","malathion","imidacloprid","spinosad"]
#       2 effectiveness=[75,85,70,90,88]
# ----> 3 pesticide_effectiveness.sort()
#
# AttributeError: 'int' object has no attribute 'sort'

# %%
for i in range(len(pesticides)):
  if effectiveness[i]>=85:
    print("pesticides suitable for organic farming are",pesticides[i])
# Out:
# pesticides suitable for organic farming are chlorpyrifos
# pesticides suitable for organic farming are imidacloprid
# pesticides suitable for organic farming are spinosad

# %%
for i in range(len(pesticides)):
  if effectiveness[i]<75:
   print("pesticide  not recommended is:",pesticides[i])
# Out:
# pesticide  not recommended is: malathion

# %%
for i in range(len(pesticides)):
  if effectiveness[i]<75:
   pesticides[i]="not recommended"
   print("updated list of pesticides:",pesticides)
# Out:
# updated list of pesticides: ['neem oil', 'chlorpyrifos', 'not recommended', 'imidacloprid', 'spinosad']

# %%
pesticide_effectiveness.sort()
print(pesticide_effectiveness)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-470717059.py in <cell line: 0>()
# ----> 1 pesticide_effectiveness.sort()
#       2 print(pesticide_effectiveness)
#
# AttributeError: 'int' object has no attribute 'sort'

# %%
pesticides=["neem oil","chlorpyrifos","malathion","imidacloprid","spinosad"]
effectiveness=[75,85,70,90,88]

# %%
equipment=["tractor","plough","harvester","seeder","sprayer","thresher"]
cost=[850000,25000,1200000,60000,18000,95000]
most_expensive_equipment=max(zip(cost,equipment))
print("most expensive equipment:",most_expensive_equipment)
# Out:
# most expensive equipment: (1200000, 'harvester')

# %%
least_expensive_equipment=min(zip(cost,equipment))
print("least expensive equipment:",least_expensive_equipment)
# Out:
# least expensive equipment: (18000, 'sprayer')

# %%
average_cost=sum(cost)/len(cost)
print("average_cost:",average_cost,"%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1110808721.py in <cell line: 0>()
# ----> 1 average_cost=sum(cost)/len(cost)
#       2 print("average_cost:",average_cost,"%")
#
# NameError: name 'cost' is not defined

# %%
equipment=["tractor","plough","harvester","seeder","sprayer","thresher"]
cost=[850000,25000,1200000,60000,18000,95000]
average_cost=sum(cost)/len(cost)
print("average_cost:",average_cost,"%")
# Out:
# average_cost: 374666.6666666667 %

# %%
equipment=["tractor","plough","harvester","seeder","sprayer","thresher"]
cost=[850000,25000,1200000,60000,18000,95000]
average_cost=sum(cost)/len(cost)
for c,e in zip(cost,equipment):
 if c == average_cost:
   print("equipment with average cost:",e)
